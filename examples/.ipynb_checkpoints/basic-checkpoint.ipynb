# %%
import sys
sys.path.append('../')
import qteasy as qt
import numpy as np
import pandas as pd
# %matplotlib inline
# Out:
# Module qteasy has been loaded successfully!, version: 0.1
# pandas version: 0.25.1
# numpy version: 1.17.2
# tushare version: 1.2.48

# %%
qt.candle('000005.SZ', start='2019-01-01', end='2019-12-31')
# Out:
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 19990 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 32426 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26143 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 19990 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 32426 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26143 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 28304 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
class CustomRollingTiming(qt.RollingTiming):
    """自定义策略"""
    # TODO: 这里需要修改super().__init__()方法，使得所有参数的设置从该方法中解放出来，允许在self.__init__()中显性设置关键参数
    def __init__(self):
        """Crossline交叉线策略只有一个动态属性，其余属性均不可变"""
        super().__init__()
        self.par_count = 4
        self.par_types = ['discr', 'discr', 'conti', 'enum']
        self.par_bounds_or_enums = [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
        self.stg_name = 'CUSTOM ROLLING TIMING STRATEGY'
        self.stg_text = 'Customized Rolling Timing Strategy for Testing'
        self.data_types = 'close, open'
        print(f'=====================\n====================\n'
              f'custom strategy initialized, \npars: {self.pars}\npar_count:{self.par_count}\npar_types:'
              f'{self.par_types}')

    def _realize(self, hist_price, params):
        """crossline策略使用四个参数：
        s：短均线计算日期；l：长均线计算日期；m：均线边界宽度；hesitate：均线跨越类型"""
        s, l, m, hesitate = params
        # 临时处理措施，在策略实现层对传入的数据切片，后续应该在策略实现层以外事先对数据切片，保证传入的数据符合data_types参数即可
        h = hist_price.T
        # 计算长短均线之间的距离
        diff = (qt.sma(h[0], l) - qt.sma(h[0], s))[-1]
        # 根据观望模式在不同的点位产生Long/short标记
        if hesitate == 'buy':
            m = -m
        elif hesitate == 'sell':
            pass
        else:  # hesitate == 'none'
            m = 0
        if diff < m:
            return 1
        else:
            return 0


class CustomSimpleTiming(qt.SimpleTiming):
    """自定义策略"""

    def __init__(self, pars: tuple = None):
        """Crossline交叉线策略只有一个动态属性，其余属性均不可变"""
        super().__init__()
        self.par_count = 4
        self.par_types = ['discr', 'discr', 'conti', 'enum']
        self.par_bounds_or_enums = [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
        self.stg_name = 'CUSTOM SIMPLE'
        self.stg_text = 'Customized Simple Timing Strategy for Testing'
        self.data_types = 'open, close'
        print(f'=====================\n====================\n'
              f'custom strategy initialized, \npars: {self.pars}\npar_count:{self.par_count}\npar_types:'
              f'{self.par_types}')

    def _realize(self, hist_price, params):
        """crossline策略使用四个参数：
        s：短均线计算日期；l：长均线计算日期；m：均线边界宽度；hesitate：均线跨越类型"""
        s, l, m, hesitate = params
        h = hist_price.T
        # 计算长短均线之间的距离
        diff = (qt.sma(h[0], l) - qt.sma(h[0], s))
        # 根据观望模式在不同的点位产生Long/short标记
        if hesitate == 'buy':
            cat = np.where(diff < -m, 1, 0)
        elif hesitate == 'sell':
            cat = np.where(diff < m, 1, 0)
        else:  # hesitate == 'none'
            cat = np.where(diff < 0, 1, 0)
        return cat

# %%
custom_rolling = CustomRollingTiming()
custom_simple = CustomSimpleTiming()
op = qt.Operator(timing_types=[custom_simple, custom_simple, custom_simple, custom_simple],
                  selecting_types=['all'], ricon_types=['urgent'])
# Out:
# =====================
# ====================
# custom strategy initialized,
# pars: None
# par_count:4
# par_types:['discr', 'discr', 'conti', 'enum']
# =====================
# ====================
# custom strategy initialized,
# pars: None
# par_count:4
# par_types:['discr', 'discr', 'conti', 'enum']

# %%
op.set_parameter('s-0', pars=(2,), sample_freq='y')
# Out:
# <class 'qteasy.operator.SelectingSimple'>
# Strategy type: SELECTING
# Information of the strategy: SIMPLE SELECTING, Selecting all share and distribute weights evenly
# Optimization Tag and opti ranges: 0, [(0, 1)]
# Parameter Loaded; <class 'tuple'>, (2,)
#  parameter has been set to (2,)
# <class 'qteasy.operator.SelectingSimple'>
# Strategy type: SELECTING
# Information of the strategy: SIMPLE SELECTING, Selecting all share and distribute weights evenly
# Optimization Tag and opti ranges: 0, [(0, 1)]
# Parameter Loaded; <class 'tuple'>, (2,)
#  history looping parameter has been set to:
#  sample frequency: y
#  window length: None
# data types: None

# %%
op.set_parameter('t-0', opt_tag=1, par_boes=[(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')])
op.set_parameter('t-1', opt_tag=1, par_boes=[(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')])
op.set_parameter('t-2', opt_tag=1, par_boes=[(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')])
op.set_parameter('t-3', opt_tag=1, par_boes=[(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')])
op.set_parameter('r-0', opt_tag=1, par_boes=[(5, 14), (-0.2, 0)])
# Out:
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, []
# Parameter NOT loaded!
#  optimizaiton tag has been set to 1
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter NOT loaded!
#  parameter space range or enum has been set to [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter NOT loaded!
#  optimizaiton tag has been set to 1
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter NOT loaded!
#  parameter space range or enum has been set to [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter NOT loaded!
#  optimizaiton tag has been set to 1
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter NOT loaded!
#  parameter space range or enum has been set to [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter NOT loaded!
#  optimizaiton tag has been set to 1
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter NOT loaded!
#  parameter space range or enum has been set to [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# <class 'qteasy.operator.RiconUrgent'>
# Strategy type: RICON
# Information of the strategy: URGENT, Generate selling signal when N-day drop rate reaches target
# Optimization Tag and opti ranges: 1, [(1, 40), (-0.5, 0.5)]
# Parameter NOT loaded!
#  optimizaiton tag has been set to 1
# <class 'qteasy.operator.RiconUrgent'>
# Strategy type: RICON
# Information of the strategy: URGENT, Generate selling signal when N-day drop rate reaches target
# Optimization Tag and opti ranges: 1, [(5, 14), (-0.2, 0)]
# Parameter NOT loaded!
#  parameter space range or enum has been set to [(5, 14), (-0.2, 0)]

# %%
cont = qt.Context(moq=0)
cont.reference_asset = '000300.SH'
cont.reference_asset_type = 'I'
cont.share_pool = '000300.SH'  # '000001.SZ, 000002.SZ, 000005.SZ, 000651.SZ, 601398.SH'
cont.asset_type = 'I'
cont.output_count = 50
cont.invest_start = '20060101'
cont.moq = 1
print(cont)
# Out:
# <class 'qteasy.core.Context'> at 0x7fd5bac276d8qteasy running information:===========================execution mode:          1 - Back-looping Mode

# %%
timing_pars1 = (94, 36, 107)
timing_pars2 = {'000100': (77, 118, 144),
                '000200': (75, 128, 138),
                '000300': (73, 120, 143)}
timing_pars3 = (98, 177, 158)
timing_pars4 = (37, 44)
timing_pars5 = (228, 83, 8.05, 'buy')
op.set_blender('timing', 'cumulative')
op.set_parameter(stg_id='t-0', pars=timing_pars5)
op.set_parameter(stg_id='t-1', pars=timing_pars5)
op.set_parameter(stg_id='t-2', pars=timing_pars5)
op.set_parameter(stg_id='t-3', pars=timing_pars5)
op.set_parameter('r-0', pars=(6, -0.06))
# Out:
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter Loaded; <class 'tuple'>, (228, 83, 8.05, 'buy')
#  parameter has been set to (228, 83, 8.05, 'buy')
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter Loaded; <class 'tuple'>, (228, 83, 8.05, 'buy')
#  parameter has been set to (228, 83, 8.05, 'buy')
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter Loaded; <class 'tuple'>, (228, 83, 8.05, 'buy')
#  parameter has been set to (228, 83, 8.05, 'buy')
# <class '__main__.CustomSimpleTiming'>
# Strategy type: RICON
# Information of the strategy: CUSTOM SIMPLE, Customized Simple Timing Strategy for Testing
# Optimization Tag and opti ranges: 1, [(10, 250), (10, 250), (0.0, 10.0), ('buy', 'sell', 'none')]
# Parameter Loaded; <class 'tuple'>, (228, 83, 8.05, 'buy')
#  parameter has been set to (228, 83, 8.05, 'buy')
# <class 'qteasy.operator.RiconUrgent'>
# Strategy type: RICON
# Information of the strategy: URGENT, Generate selling signal when N-day drop rate reaches target
# Optimization Tag and opti ranges: 1, [(5, 14), (-0.2, 0)]
# Parameter Loaded; <class 'tuple'>, (6, -0.06)
#  parameter has been set to (6, -0.06)

# %%
cont.parallel = True
cont.mode = 1
qt.run(op, cont)
cont.mode = 0
qt.run(op, cont)
cont.mode = 2
cont.opti_method = 1
cont.opti_method_sample_size = 300
cont.opti_method_step_size = 32
cont.opti_method_init_step_size = 16
cont.opti_method_min_step_size = 1
cont.opti_method_incre_ratio = 2
qt.run(op, cont)
# Out:
# preparing historical data,
# investment start date: 20041107,
# operation generation dependency start date: 20041107
# end date: 20200813
# shares: 000300.SH
# htypes: ['open', 'close'] at frequency 'd'
# Getting price type historical data...
# Getting price type historical data...
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3553 entries, 2006-01-04 to 2020-08-13
# Data columns (total 1 columns):
# 000300.SH    3553 non-null float64
# dtypes: float64(1)
# memory usage: 55.5 KB
#
# <class 'qteasy.history.HistoryPanel'>
# History Panel at 0x7fd5bb2d7e10
# Datetime Range: 3795 entries, 2005-01-04 00:00:00 to 2020-08-13 00:00:00
# Historical Data Types (total 2 data types):
# ['close', 'open']
# Shares (total 1 shares):
# non-null values for each share and data type:
#            close  open
# 000300.SH   3795  3795
# memory usage: 60848 bytes
#
# reference hist data downloaded, info:
# None
# operation hist data downloaded, info:
# None
# ====================================
#        RUNNING IN MODE 1
#       --Back-looping Mode--
# ====================================
#
# 交易日期:2006/08/02
# 考虑现金增值, 上期现金: 0.00, 经过0天后现金增值到0.00
# 本期新增投入现金, 本期现金: 0.00, 追加投资后现金增加到10000.00
# 本期开始, 期初现金: 10000.00, 期初总资产: 10000.00
# 本期交易信号[-1.]
# 以本期资产价格[1275.088]出售资产 [0.]
# 获得现金:0.00, 产生交易费用 0.00
# 本期计划买入资产动用资金: 0.00
# 以本期资产价格[1275.088]买入资产 [0.]
# 实际花费现金 0.00 并产生交易费用: -0.00
# 期末现金: 10000.00, 期末总资产: 10000.00
#
# 交易日期:2010/05/04
# 考虑现金增值, 上期现金: 10000.00, 经过1371天后现金增值到11645.20
# 本期开始, 期初现金: 11645.20, 期初总资产: 11645.20
# 本期交易信号[1.]
# 以本期资产价格[3019.449]出售资产 [-0.]
# 获得现金:0.00, 产生交易费用 0.00
# 本期计划买入资产动用资金: 11645.20
# 以本期资产价格[3019.449]买入资产 [3.]
# 实际花费现金 -9085.52 并产生交易费用: 27.18
# 期末现金: 2559.68, 期末总资产: 11618.02
#
# 交易日期:2010/05/06
# 考虑现金增值, 上期现金: 2559.68, 经过2天后现金增值到2560.29
# 本期开始, 期初现金: 2560.29, 期初总资产: 11250.86
# 本期交易信号[-1.]
# 以本期资产价格[2896.856]出售资产 [3.]
# 获得现金:8681.88, 产生交易费用 -8.69
# 本期计划买入资产动用资金: 0.00
# 以本期资产价格[2896.856]买入资产 [0.]
# 实际花费现金 0.00 并产生交易费用: -0.00
# 期末现金: 11242.17, 期末总资产: 11242.17
#
# 交易日期:2011/07/20
# 考虑现金增值, 上期现金: 11242.17, 经过440天后现金增值到11835.76
# 本期开始, 期初现金: 11835.76, 期初总资产: 11835.76
# 本期交易信号[1.]
# 以本期资产价格[3091.567]出售资产 [-0.]
# 获得现金:0.00, 产生交易费用 0.00
# 本期计划买入资产动用资金: 11835.76
# 以本期资产价格[3091.567]买入资产 [3.]
# 实际花费现金 -9302.53 并产生交易费用: 27.82
# 期末现金: 2533.23, 期末总资产: 11807.93
#
# 交易日期:2011/08/08
# 考虑现金增值, 上期现金: 2533.23, 经过19天后现金增值到2539.01
# 本期开始, 期初现金: 2539.01, 期初总资产: 10920.70
# 本期交易信号[-1.]
# 以本期资产价格[2793.897]出售资产 [3.]
# 获得现金:8373.31, 产生交易费用 -8.38
# 本期计划买入资产动用资金: 0.00
# 以本期资产价格[2793.897]买入资产 [0.]
# 实际花费现金 0.00 并产生交易费用: -0.00
# 期末现金: 10912.32, 期末总资产: 10912.32
#
# 交易日期:2013/08/12
# 考虑现金增值, 上期现金: 10912.32, 经过735天后现金增值到11874.78
# 本期开始, 期初现金: 11874.78, 期初总资产: 11874.78
# 本期交易信号[1.]
# 以本期资产价格[2352.794]出售资产 [-0.]
# 获得现金:0.00, 产生交易费用 0.00
# 本期计划买入资产动用资金: 11874.78
# 以本期资产价格[2352.794]买入资产 [5.]
# 实际花费现金 -11799.26 并产生交易费用: 35.29
# 期末现金: 75.52, 期末总资产: 11839.49
#
# 交易日期:2014/02/25
# 考虑现金增值, 上期现金: 75.52, 经过197天后现金增值到77.31
# 本期开始, 期初现金: 77.31, 期初总资产: 10866.85
# 本期交易信号[-1.]
# 以本期资产价格[2157.909]出售资产 [5.]
# 获得现金:10778.76, 产生交易费用 -10.79
# 本期计划买入资产动用资金: 0.00
# 以本期资产价格[2157.909]买入资产 [0.]
# 实际花费现金 0.00 并产生交易费用: -0.00
# 期末现金: 10856.06, 期末总资产: 10856.06
#
# 交易日期:2015/10/19
# 考虑现金增值, 上期现金: 10856.06, 经过601天后现金增值到11639.00
# 本期开始, 期初现金: 11639.00, 期初总资产: 11639.00
# 本期交易信号[1.]
# 以本期资产价格[3534.1821]出售资产 [-0.]
# 获得现金:0.00, 产生交易费用 0.00
# 本期计划买入资产动用资金: 11639.00
# 以本期资产价格[3534.1821]买入资产 [3.]
# 实际花费现金 -10634.35 并产生交易费用: 31.81
# 期末现金: 1004.65, 期末总资产: 11607.19
#
# 交易日期:2015/11/27
# 考虑现金增值, 上期现金: 1004.65, 经过39天后现金增值到1009.35
# 本期开始, 期初现金: 1009.35, 期初总资产: 11680.33
# 本期交易信号[-1.]
# 以本期资产价格[3556.9924]出售资产 [3.]
# 获得现金:10660.31, 产生交易费用 -10.67
# 本期计划买入资产动用资金: 0.00
# 以本期资产价格[3556.9924]买入资产 [0.]
# 实际花费现金 0.00 并产生交易费用: -0.00
# 期末现金: 11669.65, 期末总资产: 11669.65
#
# 交易日期:2018/06/11
# 考虑现金增值, 上期现金: 11669.65, 经过927天后现金增值到12967.79
# 本期开始, 期初现金: 12967.79, 期初总资产: 12967.79
# 本期交易信号[1.]
# 以本期资产价格[3779.9818]出售资产 [-0.]
# 获得现金:0.00, 产生交易费用 0.00
# 本期计划买入资产动用资金: 12967.79
# 以本期资产价格[3779.9818]买入资产 [3.]
# 实际花费现金 -11373.97 并产生交易费用: 34.02
# 期末现金: 1593.82, 期末总资产: 12933.77
#
# 交易日期:2018/06/21
# 考虑现金增值, 上期现金: 1593.82, 经过10天后现金增值到1595.73
# 本期开始, 期初现金: 1595.73, 期初总资产: 12374.63
# 本期交易信号[-1.]
# 以本期资产价格[3592.965]出售资产 [3.]
# 获得现金:10768.12, 产生交易费用 -10.78
# 本期计划买入资产动用资金: 0.00
# 以本期资产价格[3592.965]买入资产 [0.]
# 实际花费现金 0.00 并产生交易费用: -0.00
# 期末现金: 12363.85, 期末总资产: 12363.85
#
# 交易日期:2020/05/29
# 考虑现金增值, 上期现金: 12363.85, 经过708天后现金增值到13414.28
# 本期开始, 期初现金: 13414.28, 期初总资产: 13414.28
# 本期交易信号[1.]
# 以本期资产价格[3867.0232]出售资产 [-0.]
# 获得现金:0.00, 产生交易费用 0.00
# 本期计划买入资产动用资金: 13414.28
# 以本期资产价格[3867.0232]买入资产 [3.]
# 实际花费现金 -11635.87 并产生交易费用: 34.80
# 期末现金: 1778.41, 期末总资产: 13379.48
#
# 交易日期:2020/06/05
# 考虑现金增值, 上期现金: 1778.41, 经过7天后现金增值到1779.90
# 本期开始, 期初现金: 1779.90, 期初总资产: 13783.66
# 本期交易信号[-1.]
# 以本期资产价格[4001.2509]出售资产 [3.]
# 获得现金:11991.75, 产生交易费用 -12.00
# 本期计划买入资产动用资金: 0.00
# 以本期资产价格[4001.2509]买入资产 [0.]
# 实际花费现金 0.00 并产生交易费用: -0.00
# 期末现金: 13771.65, 期末总资产: 13771.65
#
# 交易日期:2020/06/22
# 考虑现金增值, 上期现金: 13771.65, 经过17天后现金增值到13799.75
# 本期开始, 期初现金: 13799.75, 期初总资产: 13799.75
# 本期交易信号[1.]
# 以本期资产价格[4102.0459]出售资产 [-0.]
# 获得现金:0.00, 产生交易费用 0.00
# 本期计划买入资产动用资金: 13799.75
# 以本期资产价格[4102.0459]买入资产 [3.]
# 实际花费现金 -12343.06 并产生交易费用: 36.92
# 期末现金: 1456.69, 期末总资产: 13762.83
#
# 交易日期:2020/07/07
# 考虑现金增值, 上期现金: 1456.69, 经过15天后现金增值到1459.31
# 本期开始, 期初现金: 1459.31, 期初总资产: 15553.69
# 本期交易信号[-1.]
# 以本期资产价格[4698.1264]出售资产 [3.]
# 获得现金:14080.28, 产生交易费用 -14.09
# 本期计划买入资产动用资金: 0.00
# 以本期资产价格[4698.1264]买入资产 [0.]
# 实际花费现金 0.00 并产生交易费用: -0.00
# 期末现金: 15539.60, 期末总资产: 15539.60
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:63: RuntimeWarning: invalid value encountered in less
# ====================================
#            LOOPING RESULT
# ====================================
#
# qteasy running mode: 1 - History back looping
# time consumption for operate signal creation: 23.4ms ms
# time consumption for operation back looping: 151.1ms ms
#
# investment starts on 2006-08-02 00:00:00
# ends on 2020-08-13 00:00:00
# Total looped periods: 14.0 years.
# operation summary:
#             sell  buy  total
# 000300.SH     7    7     14
# Total operation fee:     ¥     152.43
# total investment amount: ¥  10,000.00
# final value:             ¥  15,539.60
# Total return: 155.396%
# Average Yearly return rate:  3.199%
# Total reference return: 363.560%
# Average Yearly reference return rate: 9.629%
# strategy performance indicators:
# alpha:               -0.003
# Beta:                0.002
# Sharp rate:          -0.031
# 250 day volatility:  0.101
# Max drawdown:        13.928% on 2014-02-25 00:00:00
#
# ===========END OF REPORT=============
#
# preparing historical data,
# investment start date: 20041107,
# operation generation dependency start date: 20041107
# end date: 20200813
# shares: 000300.SH
# htypes: ['open', 'close'] at frequency 'd'
# Getting price type historical data...
# Getting price type historical data...
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3553 entries, 2006-01-04 to 2020-08-13
# Data columns (total 1 columns):
# 000300.SH    3553 non-null float64
# dtypes: float64(1)
# memory usage: 55.5 KB
#
# <class 'qteasy.history.HistoryPanel'>
# History Panel at 0x7fd5b5b55e80
# Datetime Range: 3795 entries, 2005-01-04 00:00:00 to 2020-08-13 00:00:00
# Historical Data Types (total 2 data types):
# ['close', 'open']
# Shares (total 1 shares):
# non-null values for each share and data type:
#            close  open
# 000300.SH   3795  3795
# memory usage: 60848 bytes
#
# reference hist data downloaded, info:
# None
# operation hist data downloaded, info:
# None
# ====================================
#        RUNNING IN MODE 0
#       --Real-time Running Mode--
# ====================================
#
# ====================================
#         OPERATION SIGNALS
# ====================================
#
# time consumption for operate signal creation: 16.2ms
#
# Operation signals are generated on 2006-08-02 00:00:00
# ends on 2020-07-07 00:00:00
# Total signals generated: 15.
# Operation signal for shares on 2020-07-07
# share 000300.SH:
# Sell out 100.0% of current on holding stock!
#
# ===========END OF REPORT=============
#
# preparing historical data,
# investment start date: 20041107,
# operation generation dependency start date: 20041107
# end date: 20200813
# shares: 000300.SH
# htypes: ['open', 'close'] at frequency 'd'
# Getting price type historical data...
# Getting price type historical data...
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3553 entries, 2006-01-04 to 2020-08-13
# Data columns (total 1 columns):
# 000300.SH    3553 non-null float64
# dtypes: float64(1)
# memory usage: 55.5 KB
#
# <class 'qteasy.history.HistoryPanel'>
# History Panel at 0x7fd5bb2d7f98
# Datetime Range: 3795 entries, 2005-01-04 00:00:00 to 2020-08-13 00:00:00
# Historical Data Types (total 2 data types):
# ['close', 'open']
# Shares (total 1 shares):
# non-null values for each share and data type:
#            close  open
# 000300.SH   3795  3795
# memory usage: 60848 bytes
#
# reference hist data downloaded, info:
# None
# operation hist data downloaded, info:
# None
# ====================================
#        RUNNING IN MODE 2
#       --Optimization Mode--
# ====================================
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:65: RuntimeWarning: invalid value encountered in less
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in less
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:65: RuntimeWarning: invalid value encountered in less
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:65: RuntimeWarning: invalid value encountered in less
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in less
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:65: RuntimeWarning: invalid value encountered in less
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in less
# Optimization progress: [####------------------------------------] 30/300. 10.0%
# /Users/jackie/anaconda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:67: RuntimeWarning: invalid value encountered in less
# Optimization progress: [########################################] 300/300. 100.0%
# Optimization completed, total time consumption: 7"022
#
# ==========SEARCHING FINISHED===============
# Searching finished, 50 best results are generated
# The best parameter performs 1.610 times better than the least performing result
# best result: 96560.370 obtained at parameter:
# (63, 71, 5.734127044822407, 'sell', 134, 201, 7.817378955249285, 'buy', 203, 95, 4.16607382590827, 'buy', 78, 239, 6.790877376618758, 'none', 7, -0.13884272761765704)
# least result: 59981.669 obtained at parameter:
# (211, 148, 5.911230473695505, 'buy', 120, 39, 6.138420309723761, 'sell', 203, 148, 6.545839178832155, 'buy', 97, 197, 5.617588734373042, 'none', 11, -0.15018665863151548)
# complete list of performance and parameters are following,
#                                                                0
# (211, 148, 5.911230473695505, buy, 120, 39, 6.1...  59981.668965
# (167, 193, 0.44883078729492376, none, 164, 112,...  60092.539338
# (94, 143, 4.21032955772302, none, 183, 68, 2.40...  60173.890993
# (109, 99, 8.117682895052043, buy, 177, 232, 4.6...  60215.791299
# (212, 138, 0.33867908988418516, sell, 198, 210,...  60666.642889
# (195, 242, 2.0694378923456647, none, 14, 102, 9...  60776.945306
# (24, 123, 1.6223552864828805, none, 110, 138, 2...  61676.083074
# (208, 128, 5.324178013203746, sell, 21, 135, 9....  62309.661076
# (114, 103, 1.981692795645611, none, 174, 158, 3...  62777.526823
# (84, 32, 9.873864430002952, none, 179, 13, 5.15...  63217.712199
# (56, 41, 3.948147607995398, sell, 238, 123, 3.8...  63871.364878
# (27, 63, 3.462375622860392, none, 19, 142, 5.06...  64866.430490
# (107, 226, 7.472620322715158, buy, 141, 228, 9....  66907.103421
# (184, 142, 7.745984800743725, none, 107, 210, 1...  66955.294426
# (162, 96, 9.07810517956208, sell, 16, 30, 4.163...  67935.315780
# (56, 134, 0.6393781007870469, buy, 151, 96, 0.8...  68360.988475
# (85, 211, 6.534792645185526, buy, 80, 156, 7.60...  68530.478173
# (191, 95, 5.305577972686599, buy, 221, 72, 8.31...  69589.654270
# (229, 198, 0.5825374622551882, buy, 127, 161, 5...  69842.610397
# (18, 230, 3.1745070162359457, none, 39, 182, 1....  70950.498305
# (13, 35, 9.611637801122022, sell, 33, 205, 9.47...  71297.080974
# (85, 136, 6.332711121098484, none, 170, 54, 5.3...  71340.244483
# (203, 214, 0.7540699546837704, buy, 50, 134, 8....  72898.980072
# (189, 123, 6.391668182220628, sell, 206, 146, 2...  73401.133345
# (77, 36, 9.688551559818517, none, 154, 98, 9.48...  73549.185892
# (31, 217, 4.02857355100974, sell, 54, 176, 2.21...  73950.374033
# (180, 79, 5.048942632887753, buy, 237, 63, 0.41...  74440.269591
# (91, 205, 6.037205613696047, none, 208, 232, 9....  74885.659862
# (64, 12, 6.592996845142736, sell, 200, 138, 1.3...  75387.990015
# (201, 175, 4.078366559421566, buy, 163, 41, 5.6...  76110.617619
# (170, 67, 3.2757771898927404, buy, 211, 112, 4....  76670.769035
# (165, 50, 3.5347219553577336, sell, 206, 37, 8....  77292.700651
# (121, 132, 3.257811570997635, none, 209, 239, 8...  77732.037107
# (214, 161, 3.985398911118765, sell, 166, 121, 7...  78180.671411
# (189, 209, 3.512172288509263, sell, 239, 79, 2....  78707.104425
# (235, 188, 9.994039924084724, buy, 74, 143, 3.1...  78854.554766
# (27, 20, 5.930599915814868, none, 132, 63, 7.25...  79031.846971
# (219, 124, 8.13021538808774, sell, 64, 199, 5.2...  79305.879597
# (238, 156, 8.652620127835283, none, 140, 218, 3...  79415.387838
# (55, 185, 9.387394137623236, buy, 174, 176, 5.2...  82043.219871
# (93, 19, 2.960383114171672, buy, 57, 214, 3.583...  83572.090440
# (104, 235, 4.7589561832645515, none, 91, 47, 4....  86096.529830
# (146, 115, 4.902969731219549, sell, 235, 174, 5...  86262.661642
# (73, 248, 8.448568015766835, buy, 18, 84, 0.178...  88398.122548
# (70, 125, 9.736126100683256, none, 82, 218, 1.4...  89372.775893
# (112, 243, 5.255657163172918, sell, 167, 18, 1....  89402.098178
# (10, 249, 0.6399581354785266, none, 158, 140, 9...  89649.205567
# (42, 58, 5.398846210770236, sell, 188, 37, 3.10...  92210.206704
# (201, 123, 4.239168180666298, buy, 52, 218, 9.2...  94044.047766
# (63, 71, 5.734127044822407, sell, 134, 201, 7.8...  96560.370090
# ==========OPTIMIZATION COMPLETE============
